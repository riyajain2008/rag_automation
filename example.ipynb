# %%
1+1
# Out:
# 2

# %%
from langchain_core.documents import Document
doc = Document(page_content="This is a test document.", metadata={"source": "test.txt"})
# Out:
# This is a test document.
# {'source': 'test.txt'}
# page_content='This is a test document.' metadata={'source': 'test.txt'}

# %%
from langchain_community.document_loaders import TextLoader



loader = TextLoader("data/python_intro.txt")

#documents = loader.load()
documents = loader.load() 
print(documents.page_content)
# Out:
# [Document(metadata={'source': 'data/python_intro.txt'}, page_content='This is intro to RAG course, where I am building a RAG from scratch')]
